# %%
import json
import os
import asyncio
from get_notebook_data import get_all_notebook_data

# %%
import nest_asyncio
nest_asyncio.apply()

# %%
asyncio.run(get_all_notebook_data())
# Out:
# Connecting to NotebookLM...
# Fetching notebooks...
# Found 20 notebooks.
# Processing (1/20): Analysis: test.pdf
#   -> 1 sources, 0 notes
# Processing (2/20): Analysis: analyze_f06e334f-fecc-4918-9d77-6d084ac0f5ad.pdf
#   -> 1 sources, 0 notes
# Processing (3/20): Analysis: analyze_ea033d51-f571-4db2-b824-d3d378b4bd28.pdf
#   -> 1 sources, 0 notes
# Processing (4/20): Analysis: analyze_f879ea10-f2bb-4fcb-9b92-ccdb73c75f35.pdf
#   -> 1 sources, 0 notes
# Processing (5/20): Analysis: analyze_d5ebb072-2f31-4776-b704-4cf3da8dc0b1.pdf
#   -> 1 sources, 0 notes
# Processing (6/20): Analysis: analyze_7a717285-e2e3-4711-a637-8f90f061fd50.pdf
#   -> 1 sources, 0 notes
# Processing (7/20): Analysis: analyze_0dbe0377-738e-4ac9-acaa-1e738449deb2.pdf
#   -> 1 sources, 0 notes
# Processing (8/20): Analysis: analyze_4fc9a3fe-7a1c-4db0-83cc-a5b01c6580bd.pdf
#   -> 1 sources, 0 notes
# Processing (9/20): Analysis: analyze_376a0e7e-18e2-47e9-af4b-7b9898e3a5ef.pdf
#   -> 1 sources, 0 notes
# ...

# %%
with open("all_notebook_data.json", 'r') as reader:
    notebook_data = json.loads(reader.read())

# %% [markdown]
# # 刪除 notebook lm 的筆記

# %%
import asyncio
import os
import json
import re
from notebooklm import NotebookLMClient

# %%
async with await NotebookLMClient.from_storage() as client:
    # Process videos one by one (or in small batches if needed)
    for note in notebook_data:
        # Cleanup: Delete notebook
        await client.notebooks.delete(note["notebook_id"])
        print("Notebook deleted.")
        await asyncio.sleep(2)
# Out:
# Notebook deleted.
# Notebook deleted.
# Notebook deleted.
# Notebook deleted.
# Notebook deleted.
# Notebook deleted.
# Notebook deleted.
# Notebook deleted.
# Notebook deleted.
# Notebook deleted.
# Notebook deleted.
# Notebook deleted.
# Notebook deleted.
# Notebook deleted.
# Notebook deleted.
# Notebook deleted.
# Notebook deleted.
# Notebook deleted.
# Notebook deleted.
# Notebook deleted.
